# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv(r"C:\Users\Raman\Desktop\DESKTOP\p and g\Data Analysis\data\cleaned_with_targeted_personas.csv")
df
# Out:
#      Unnamed: 0  gender age_group familiarity_with_herbal_essences  \
# 0             0    MALE     18-25                Somewhat familiar
# 1             1    MALE     18-25                Somewhat familiar
# 2             2  FEMALE     18-25                Somewhat familiar
# 3             3  FEMALE     18-25                Never heard of it
# 4             4    MALE     18-25                Somewhat familiar
# ..          ...     ...       ...                              ...
# 177         177    MALE     18-25                Never heard of it
# 178         178  FEMALE     18-25                Somewhat familiar
# 179         179  FEMALE     18-25                Never heard of it
# 180         180  FEMALE     18-25                    Very familiar
# 181         181  FEMALE     18-25                Never heard of it
#
#            respondent_location hair_care_routine_story  \
# 0                Not Specified         Nature inspired
# ...

# %% [markdown]
# Now our primary target will be Wellness and quality seeker segment

# %%
df_target_segment = df[df['persona']=="Wellness and Quality Seeker"]
df.head()
# Out:
#    Unnamed: 0  gender age_group familiarity_with_herbal_essences  \
# 0           0    MALE     18-25                Somewhat familiar
# 1           1    MALE     18-25                Somewhat familiar
# 2           2  FEMALE     18-25                Somewhat familiar
# 3           3  FEMALE     18-25                Never heard of it
# 4           4    MALE     18-25                Somewhat familiar
#
#   respondent_location hair_care_routine_story ideal_hair_care_product_message  \
# 0       Not Specified         Nature inspired                   Gentle-Caring
# 1       Not Specified            Time-Pressed               Naturally Healthy
# 2       Not Specified         Nature inspired                   Gentle-Caring
# 3       Not Specified              Cost-Aware               Naturally Healthy
# 4       Not Specified         Nature inspired         Personalization-Focused
#
#       celeb_hair_care_philosophy  current_natural_shampoo_user  \
# ...

# %%
marketing_branding_columns = [
    'ideal_hair_care_product_message', 
    'celeb_hair_care_philosophy', 
    'motivation_to_try_herbal_essence'
]

df_marketing_branding_insights = df_target_segment[marketing_branding_columns]
df_marketing_branding_insights.head()
# Out:
#    ideal_hair_care_product_message     celeb_hair_care_philosophy  \
# 0                    Gentle-Caring  Cultural Heritage Influencers
# 2                    Gentle-Caring                Science Experts
# 11               Naturally Healthy  Cultural Heritage Influencers
# 20               Naturally Healthy                Science Experts
# 21               Naturally Healthy  Cultural Heritage Influencers
#
#    motivation_to_try_herbal_essence
# 0                      Afordability
# 2             Trust-Based Influence
# 11                     Afordability
# 20       Evidence-Driven Motivation
# 21            Trust-Based Influence

# %%
df_marketing_branding_insights.to_csv(r"C:\Users\Raman\Desktop\DESKTOP\p and g\Data Analysis\data\marketing_branding_insights.csv", index=False)

# %%
df_non_target_segment = df[df['persona']!="Wellness and Quality Seeker"]
df_non_target_segment.head()
# Out:
#    Unnamed: 0  gender age_group familiarity_with_herbal_essences  \
# 1           1    MALE     18-25                Somewhat familiar
# 3           3  FEMALE     18-25                Never heard of it
# 4           4    MALE     18-25                Somewhat familiar
# 5           5    MALE     18-25                Somewhat familiar
# 6           6  FEMALE     18-25                Never heard of it
#
#   respondent_location hair_care_routine_story ideal_hair_care_product_message  \
# 1       Not Specified            Time-Pressed               Naturally Healthy
# 3       Not Specified              Cost-Aware               Naturally Healthy
# 4       Not Specified         Nature inspired         Personalization-Focused
# 5       Not Specified              Cost-Aware                   Gentle-Caring
# 6       Not Specified      Exploration-Driven                   Gentle-Caring
#
#   celeb_hair_care_philosophy  current_natural_shampoo_user  \
# ...

# %%
import matplotlib.pyplot as plt 
# Loop through each column in df_non_target_segment
for column in df_non_target_segment.columns:
    # Generate pie chart
    df_non_target_segment[column].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, figsize=(8, 8))
    plt.title(f'Pie Chart for {column}')
    plt.ylabel('')  # Hide the y-label
    plt.show()

# %%
# Loop through each column in df_target_segment
for column in df_target_segment.columns:
    # Generate pie chart
    df_target_segment[column].value_counts().plot.pie(autopct='%1.1f%%', startangle=90, figsize=(8, 8))
    plt.title(f'Pie Chart for {column}')
    plt.ylabel('')  # Hide the y-label
    plt.show()

# %%
def segment_market(data_file):
    """Identify key market segments"""
    df = pd.read_csv(data_file)
    segments = {
        'product_messages': df['ideal_hair_care_product_message'].value_counts(),
        'influencer_groups': df['celeb_hair_care_philosophy'].value_counts(),
        'motivations': df['motivation_to_try_herbal_essence'].value_counts()
    }
    return segments

data_file = r"C:\Users\Raman\Desktop\DESKTOP\p and g\Data Analysis\data\marketing_branding_insights.csv"
print("Market Segments:")
print(segment_market(data_file))
# Out:
# Market Segments:
# {'product_messages': ideal_hair_care_product_message
# Naturally Healthy          37
# Gentle-Caring              20
# Personalization-Focused     7
# Image-Driven                6
# Other                       2
# Name: count, dtype: int64, 'influencer_groups': celeb_hair_care_philosophy
# Cultural Heritage Influencers    30
# Science Experts                  19
# Laid-Back Trendsetters           13
# Tech-Savvy Innovators             7
# Other                             3
# Name: count, dtype: int64, 'motivations': motivation_to_try_herbal_essence
# Trust-Based Influence         27
# Afordability                  18
# Evidence-Driven Motivation    15
# Natural Product Appeal         9
# Other                          3
# Name: count, dtype: int64}

# %%
import matplotlib.pyplot as plt

# Define the segments variable
segments = segment_market(data_file)

# Create bar charts for each segment
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

# Plot product messages
axes[0].bar(segments['product_messages'].index, segments['product_messages'].values)
axes[0].set_title('Product Messages')
axes[0].set_xlabel('Message')
axes[0].set_ylabel('Count')
axes[0].tick_params(axis='x', rotation=45)
for tick in axes[0].get_xticklabels():
    tick.set_ha('right')

# Plot influencer groups
axes[1].bar(segments['influencer_groups'].index, segments['influencer_groups'].values)
axes[1].set_title('Influencer Groups')
axes[1].set_xlabel('Group')
axes[1].set_ylabel('Count')
axes[1].tick_params(axis='x', rotation=45)
for tick in axes[1].get_xticklabels():
    tick.set_ha('right')

# Plot motivations
axes[2].bar(segments['motivations'].index, segments['motivations'].values)
axes[2].set_title('Motivations')
axes[2].set_xlabel('Motivation')
axes[2].set_ylabel('Count')
axes[2].tick_params(axis='x', rotation=45)
for tick in axes[2].get_xticklabels():
    tick.set_ha('right')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Targeting Strategy
# - **Primary Message:** Naturally Healthy  & Gentle to skin
# - **Primary Influencer:** Cultural Heritage Influencers  & Science Experts
# - **Primary Motivation:** Trust-Based Influence , Afordability, and Evidence-Driven Motivation
#
#
# ---
#
# ### Campaign Ideas
# - **Science-Backed Beauty:** Cultural Heritage Influencers Approved
# - **Affordable Luxury:** Trust-Based Influence Solutions
